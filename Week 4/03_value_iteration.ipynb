# %% [markdown]
# # 03 — Value Iteration
# **Week 4 | Dynamic Programming**
#
# **Value Iteration** combines policy evaluation and improvement into a single update:
#
# $$V_{k+1}(s) = \max_a \sum_{s'} P(s'|s,a) \left[ R(s,a,s') + \gamma V_k(s') \right]$$
#
# No explicit policy during the loop — we extract the policy once V converges.

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(0)

class GridWorld:
    ACTIONS = {0:(-1,0), 1:(1,0), 2:(0,-1), 3:(0,1)}
    ACTION_SYMBOLS = {0:'↑', 1:'↓', 2:'←', 3:'→'}
    def __init__(self, size=5):
        self.size=size; self.start=(0,0); self.goal=(size-1,size-1)
        self.pits={(1,1),(1,3),(3,1),(3,3)}
    def n_states(self): return self.size**2
    def n_actions(self): return 4
    def transitions(self, s, a):
        r,c = divmod(s, self.size)
        dr,dc = self.ACTIONS[a]
        nr=max(0,min(self.size-1,r+dr)); nc=max(0,min(self.size-1,c+dc)); ns=nr*self.size+nc
        if (nr,nc)==self.goal:   return [(1.0,ns,+10.0,True)]
        if (nr,nc) in self.pits: return [(1.0,ns,-5.0,True)]
        return [(1.0,ns,-0.1,False)]

env = GridWorld()

# %%
def value_iteration(env, gamma=0.99, theta=1e-6):
    V = np.zeros(env.n_states())
    errors = []
    iteration = 0
    while True:
        delta = 0
        V_new = np.zeros_like(V)
        for s in range(env.n_states()):
            Q_s = [sum(p*(r + (0 if d else gamma*V[ns]))
                       for p,ns,r,d in env.transitions(s,a))
                   for a in range(env.n_actions())]
            V_new[s] = max(Q_s)
            delta = max(delta, abs(V_new[s] - V[s]))
        V = V_new
        errors.append(delta)
        iteration += 1
        if delta < theta:
            print(f"Value iteration converged in {iteration} sweeps (Δ={delta:.2e})")
            break
    # Extract greedy policy
    policy = np.zeros(env.n_states(), dtype=int)
    for s in range(env.n_states()):
        Q_s = [sum(p*(r + (0 if d else gamma*V[ns]))
                   for p,ns,r,d in env.transitions(s,a))
               for a in range(env.n_actions())]
        policy[s] = np.argmax(Q_s)
    return V, policy, errors

V_star, pi_star, errors = value_iteration(env)
# Out:
# Value iteration converged in 9 sweeps (Δ=0.00e+00)

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4.5))

# Value function
im = axes[0].imshow(V_star.reshape(5,5), cmap='RdYlGn')
plt.colorbar(im, ax=axes[0])
for s in range(25):
    r,c=divmod(s,5)
    label='G' if (r,c)==env.goal else ('✕' if (r,c) in env.pits else '')
    axes[0].text(c,r,f'{label}\n{V_star[s]:.1f}',ha='center',va='center',fontsize=9)
axes[0].set_title('V* (Value Iteration)'); axes[0].set_xticks([]); axes[0].set_yticks([])

# Optimal policy
axes[1].set_xlim(-0.5,4.5); axes[1].set_ylim(-0.5,4.5)
axes[1].set_xticks(range(5)); axes[1].set_yticks(range(5)); axes[1].grid(True)
for s in range(25):
    r,c=divmod(s,5)
    if (r,c)==env.goal:         axes[1].text(c,4-r,'G',ha='center',va='center',fontsize=14,color='green')
    elif (r,c) in env.pits:     axes[1].text(c,4-r,'✕',ha='center',va='center',fontsize=14,color='red')
    else:                       axes[1].text(c,4-r,env.ACTION_SYMBOLS[pi_star[s]],ha='center',va='center',fontsize=18)
axes[1].set_title('Optimal Policy π*')

# Convergence
axes[2].semilogy(errors, color='darkorange', linewidth=2)
axes[2].set_xlabel('Sweep'); axes[2].set_ylabel('Max Bellman error (log)')
axes[2].set_title('Value Iteration Convergence')
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Policy Iteration vs Value Iteration — Comparison

# %%
import time

# Time value iteration
t0 = time.time()
for _ in range(20): value_iteration(env)
vi_time = (time.time()-t0)/20

print(f"Value Iteration avg time: {vi_time*1000:.2f} ms")
print(f"\nKey difference:")
print(" Policy Iteration: full eval to convergence at each step (many inner loops)")
print(" Value Iteration:  single sweep per iteration (simpler inner loop)")
print(" Both converge to the same optimal policy.")
# Out:
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Value Iteration avg time: 5.45 ms
#
# Key difference:
#  Policy Iteration: full eval to convergence at each step (many inner loops)
#  Value Iteration:  single sweep per iteration (simpler inner loop)
#  Both converge to the same optimal policy.

# %% [markdown]
# ## ✅ Exercises
# 1. Plot V* as a 3D surface using `ax.plot_surface`. Does the shape make intuitive sense?
# 2. Set γ=0.5. Does value iteration still converge? What does the optimal policy look like now?
# 3. **Challenge**: implement **asynchronous value iteration** — update one randomly-chosen state per step. Plot the convergence and compare to synchronous.

# %% [markdown]
# Ans 1) This graoh look like - A	surface	rising	smoothly	toward	a	peak	at	the	goal
# corner	(4,4),	with	four	sharp	sinkholes	at	the	pit	cells.

# %%
from	mpl_toolkits.mplot3d	import	Axes3D			#	noqa:	F401
X,	Y	=	np.meshgrid(np.arange(5),	np.arange(5))
Z	=	V_star.reshape(5,	5)
fig	=	plt.figure(figsize=(8,	5))
ax	=	fig.add_subplot(111,	projection='3d')
surf	=	ax.plot_surface(X,	Y,	Z,	cmap='RdYlGn',	edgecolor='gray',	linewidth=0.3)
fig.colorbar(surf,	shrink=0.6)
ax.set_xlabel('Column');	ax.set_ylabel('Row');	ax.set_zlabel('V*')
ax.set_title('V*	as	a	3D	surface')
ax.view_init(elev=35,	azim=-60)
plt.tight_layout();	plt.show()
# Out:
# C:\Users\arinu\AppData\Local\Temp\ipykernel_39916\1386852556.py:11: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   plt.tight_layout();	plt.show()

# %% [markdown]
# Ans 2)

# %%
V_05,	pi_05,	err_05	=	value_iteration(env,	gamma=0.5)
print(f"Sweeps	at	γ=0.99:	{len(errors)}")
print(f"Sweeps	at	γ=0.5:		{len(err_05)}")
print("Policy	identical	to	γ=0.99	policy:",	np.array_equal(pi_05,	pi_star))
#	render	the	γ=0.5	policy
fig,	ax	=	plt.subplots(figsize=(5,	5))
ax.set_xlim(-0.5,	4.5);	ax.set_ylim(-0.5,	4.5)
ax.set_xticks(range(5));	ax.set_yticks(range(5));	ax.grid(True)
for	s	in	range(25):
				r,	c	=	divmod(s,	5)
				if	(r,c)==env.goal:					ax.text(c,	4-r,	'G',	ha='center',	va='center',	fontsize=14,	color='green')
				elif	(r,c)	in	env.pits:	ax.text(c,	4-r,	'✕',	ha='center',	va='center',	fontsize=14,	color='red')
				else:																			ax.text(c,	4-r,	env.ACTION_SYMBOLS[pi_05[s]],	ha='center',	va='center',	fontsize=18)
ax.set_title('π* at γ= 0.5');	plt.tight_layout();	plt.show()
# Out:
# Value iteration converged in 9 sweeps (Δ=0.00e+00)
# Sweeps	at	γ=0.99:	9
# Sweeps	at	γ=0.5:		9
# Policy	identical	to	γ=0.99	policy: True

# %% [markdown]
# Ans 3) Async	converges	to	the	same	V*	(guaranteed	as	long	as
# every	state	keeps	being	sampled),

# %%
def async_value_iteration(env, gamma=0.99, n_updates=20_000, eval_every=25):
    """Update one randomly chosen state per step, in place."""
    V = np.zeros(env.n_states())
    errors = []

    for i in range(n_updates):
        s = np.random.randint(env.n_states())
        Q_s = [
            sum(p * (r + (0 if d else gamma * V[ns]))
                for p, ns, r, d in env.transitions(s, a))
            for a in range(env.n_actions())
        ]
        V[s] = max(Q_s)

        if i % eval_every == 0:
            errors.append(np.max(np.abs(V - V_star)))

    return V, errors


def sync_value_iteration_errors(env, gamma=0.99, n_sweeps=200, eval_every=1):
    """Synchronous value iteration, tracking ||V - V*||_inf."""
    V = np.zeros(env.n_states())
    errors = []

    for i in range(n_sweeps):
        V_new = np.zeros_like(V)
        for s in range(env.n_states()):
            Q_s = [
                sum(p * (r + (0 if d else gamma * V[ns]))
                    for p, ns, r, d in env.transitions(s, a))
                for a in range(env.n_actions())
            ]
            V_new[s] = max(Q_s)
        V = V_new

        if i % eval_every == 0:
            errors.append(np.max(np.abs(V - V_star)))

    return V, errors


V_async, async_err = async_value_iteration(env)
V_sync, sync_err = sync_value_iteration_errors(env)

plt.figure(figsize=(9, 3.5))
plt.semilogy(sync_err, label='Synchronous (per sweep = 25 updates)', color='darkorange', linewidth=2)
plt.semilogy(async_err, label='Async (per 25 random updates)', color='steelblue', linewidth=2)
plt.xlabel('Compute (units of 25 state-updates)')
plt.ylabel('||V - V*||∞ (log)')
plt.title('Synchronous vs Asynchronous Value Iteration')
plt.legend()
plt.tight_layout()
plt.show()

print('Async converged to V*:', np.allclose(V_async, V_star, atol=1e-3))
# Out:
# Async converged to V*: True
